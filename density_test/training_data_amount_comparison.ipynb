# %%
gcn_mean_error = [2558.2284, 1066.1637, 1148.5994, 803.0847, 886.3534, 430.1662, 436.6016, 349.5924, 353.4228, 423.8367]
instance_amount = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]

# graph
import matplotlib.pyplot as plt
plt.plot(instance_amount, gcn_mean_error, label='GCN')
plt.xlabel('Instance Amount')
plt.ylabel('Mean Error')
plt.title('Mean Error of GCN')
plt.legend()

# %%
gcn_median_error = [2470.4836, 998.2975, 1078.1406, 705.9906, 863.2725, 392.0216, 375.6722, 315.2210, 307.8706, 376.0045]
instance_amount = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]

plt.figure(facecolor='w')
plt.plot(instance_amount, gcn_median_error, label='GCN')
plt.xlabel('Instance Amount')
plt.ylabel('Median Error (m)')
plt.title('Median Error of GCN')
# Out:
# Text(0.5, 1.0, 'Median Error of GCN')
