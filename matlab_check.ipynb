# %%
#check is the data in matlab/data_instance_1.mat is different from the data in matlab/data_instance_2.mat
from scipy.io import loadmat

filename = f"matlab/data_instance_1.mat"
data_instance_1 = loadmat(filename)

filename = f"matlab/data_instance_2.mat"
data_instance_2 = loadmat(filename)

data_instance_1['nodeLatitudes']
# Out:
# array([[40.4749942 ],
#        [40.49050896],
#        [40.51944169],
#        [40.53757738],
#        [40.55004891],
#        [40.47832728],
#        [40.49530842],
#        [40.5024766 ],
#        [40.5376105 ],
#        [40.54221771],
#        [40.46839026],
#        [40.48879685],
#        [40.50486569],
#        [40.52228267],
#        [40.53975706],
#        [40.47336691],
#        [40.49031549],
#        [40.51640811],
#        [40.53242582],
#        [40.53904763],
#        [40.46702789],
#        [40.49710302],
#        [40.51790142],
#        [40.52136685],
#        [40.55244295],
#        [40.49179551],
#        [40.52667492],
#        [40.52587128],
#        [40.47723066],
#        [40.50278804],
#        [40.49092745],
#        [40.53057754],
#        [40.49165485],
#        [40.54670491],
#        [40.54045085],
#        [40.50123468],
#        [40.51092538],
#        [40.52861341],
#        [40.54115064],
#        [40.52096197],
#        [40.51782752],
# ...
